# %%
# importing modules

import os
import pandas as pd

# %%
# Function to create CSV out of text files stored in various folder

def create_csv(RAW_DATA_PATH = "..\\data\\raw"):
    """ Create CSV file out of text files stored in various folder
    """
    
    SUB_FOLDERS = list(os.walk(RAW_DATA_PATH + "\\EMG_data_for_gestures-master"))[1:]

    FILE_PATHS = []
    for SUB_FOLDER in SUB_FOLDERS:
        for FILE in SUB_FOLDER[2]:
            FILE_PATHS.append(SUB_FOLDER[0] + "\\" + FILE)

    DATAFRAMES = []
    for FILE_PATH in FILE_PATHS:
        df = pd.read_csv(FILE_PATH, delimiter='\t')
        DATAFRAMES.append(df)
    Final_df = pd.concat(DATAFRAMES)
    
    return Final_df

# %%
# Function Calling

df = create_csv()
df.head()
# Out:
#    time  channel1  channel2  channel3  channel4  channel5  channel6  channel7  \
# 0     1   0.00001  -0.00002  -0.00001  -0.00003   0.00000  -0.00001   0.00000
# 1     5   0.00001  -0.00002  -0.00001  -0.00003   0.00000  -0.00001   0.00000
# 2     6  -0.00001   0.00001   0.00002   0.00000   0.00001  -0.00002  -0.00001
# 3     7  -0.00001   0.00001   0.00002   0.00000   0.00001  -0.00002  -0.00001
# 4     8  -0.00001   0.00001   0.00002   0.00000   0.00001  -0.00002  -0.00001
#
#    channel8  class
# 0  -0.00001    0.0
# 1  -0.00001    0.0
# 2   0.00001    0.0
# 3   0.00001    0.0
# 4   0.00001    0.0

# %%
# Exporting CSV

import datetime

datetime_ = datetime.datetime.now().strftime("%d-%m-%y-%H-%M-%S")
df.to_csv(f"..\\data\\interim\\gesture-prediction-{datetime_}.csv")

# %%
df = pd.read_csv('../data/interim/gesture-prediction.csv')

# %%
df.head()
# Out:
#    time  channel1  channel2  channel3  channel4  channel5  channel6  channel7  \
# 0     1   0.00001  -0.00002  -0.00001  -0.00003   0.00000  -0.00001   0.00000
# 1     5   0.00001  -0.00002  -0.00001  -0.00003   0.00000  -0.00001   0.00000
# 2     6  -0.00001   0.00001   0.00002   0.00000   0.00001  -0.00002  -0.00001
# 3     7  -0.00001   0.00001   0.00002   0.00000   0.00001  -0.00002  -0.00001
# 4     8  -0.00001   0.00001   0.00002   0.00000   0.00001  -0.00002  -0.00001
#
#    channel8  class
# 0  -0.00001    0.0
# 1  -0.00001    0.0
# 2   0.00001    0.0
# 3   0.00001    0.0
# 4   0.00001    0.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4237908 entries, 0 to 4237907
# Data columns (total 10 columns):
#  #   Column    Dtype
# ---  ------    -----
#  0   time      int64
#  1   channel1  float64
#  2   channel2  float64
#  3   channel3  float64
#  4   channel4  float64
#  5   channel5  float64
#  6   channel6  float64
#  7   channel7  float64
#  8   channel8  float64
#  9   class     float64
# dtypes: float64(9), int64(1)
# memory usage: 323.3 MB
